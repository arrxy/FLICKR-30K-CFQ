# %%
import os.path

import torch
from pyecharts.charts import *
from pyecharts import options as opts
from collections import defaultdict
import json
import os
import random
from huggingface_hub import snapshot_download

# %%
main_dir_path = '/Users/aidan/Learn/NLP/Retrieval/Construction/V8'

# %%
snapshot_download(repo_id="kakaobrain/align-base", local_dir="/Users/aidan/Learn/Tools/Models/align-base", local_dir_use_symlinks=False)
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# '/Users/aidan/Learn/Tools/Models/align-base'

# %%
train_sen_to_ids_file_path = os.path.join(main_dir_path, 'combine/data/train_sen_to_ids.json')

# %%
train_sen_to_ids = json.load(open(train_sen_to_ids_file_path, 'r', encoding='utf-8'))

# %%
text_d = defaultdict(list)
for text, item in train_sen_to_ids.items():
    text_d[item['type']].append(text)

# %%
sub_text_list = []
for _, text_list in text_d.items():
    sub_text_list.extend(random.sample(text_list, 10))

# %%
image_features = torch.load('../../../V6/retrieval/data/image_features_{}.pt'.format('align-base'), map_location=torch.device('cpu'))
